# %%
import googlemaps
import time
from tqdm import tqdm

# %%
KEY = 'AIzaSyDKzzVJyXUhmJ3a785zLtFr0pXlqkiqGrE'
amsterdam = [52.371643, 4.895542]
place_types = ['clothing_store', 'art_gallery', 'shoe_store'] # https://developers.google.com/places/supported_types

# %%
neighbourhoods = [
    'Admiralenbuurt',
'Amsteldorp',
'Amsterdam Oud-West',
'Amsterdam Oud-Zuid',
'Amsterdam Science Park',
'Apollobuurt',
'Betondorp',
'Bijlmermeer',
'Bos en Lommer',
'Buiksloot',
'Buikslotermeer',
'Buitenveldert',
'Bullewijk',
'Burgwallen Nieuwe Zijde',
'Burgwallen Oude Zijde',
'Chassébuurt',
'Cruquiuseiland',
'Czaar Peterbuurt',
'Dapperbuurt',
'De Aker',
'De Pijp',
'De Wallen',
'Diamantbuurt',
'Duivelseiland',
'Eastern Docklands',
'Eendracht',
'Floradorp',
'Frederik Hendrikbuurt',
'Gaasperdam',
'Geuzenveld',
'Gouden Reael',
'Grachtengordel',
'Haarlemmerbuurt',
'Hoofddorppleinbuurt',
'Houthaven',
'IJburg',
'Indische Buurt',
'Java-eiland',
'Jodenbuurt',
'Jordaan',
'Kadijken',
'Kadoelen',
'Kinkerbuurt',
'KNSM Island',
'Kolenkit District',
'Landelijk Noord',
'Landlust',
'Lastage',
'Middelveldsche Akerpolder',
'Molenwijk',
'Museumkwartier',
'NDSM',
'Negen Straatjes',
'Nieuw Sloten',
'Nieuwe Pijp',
'Nieuwendam',
'Nieuwendammerdijk en Buiksloterdijk',
'Olympisch Kwartier',
'Omval',
'Oostelijke Eilanden',
'Oosterdokseiland',
'Oosterparkbuurt',
'Oostoever',
'Oostpoort',
'Oostzanerwerf',
'Osdorp',
'Oud Osdorp',
'Oud-Oost',
'Oude Pijp',
'Overhoeks',
'Overtoombuurt',
'Overtoomse Veld',
'Plantage',
'Prinses Irenebuurt',
'Ransdorp',
'Rieteilanden',
'Rivierenbuurt',
'Ruigoord',
'Schellingwoude',
'Schinkelbuurt',
'Slotermeer',
'Slotervaart (neighbourhood)',
'Spaarndammerbuurt',
'Staatsliedenbuurt',
'Stadionbuurt',
'Steigereiland',
'Teleport',
'Transvaalbuurt',
'Trompbuurt',
'Tuindorp Nieuwendam',
'Tuindorp Oostzaan',
'Uilenburg',
'Venserpolder',
'Watergraafsmeer',
'Waterwijk',
'Weesperzijde',
'Westelijk Havengebied',
'Westelijke Eilanden',
'Westelijke Tuinsteden',
'Westerpark (neighbourhood)',
'Willemspark',
'Zeeburgereiland',
'Zeeheldenbuurt',
'Zuidas'
]

# %%
gmaps = googlemaps.Client(key=KEY)

# %%
places = {}

# %%
location = amsterdam
radius = 15 * 1000
type = place_types[0]

# %%
def query(text, page_token=None):
    return gmaps.places(
        text,
        location=location,
        radius=radius,
        type=type,
        page_token=page_token
    )

# %%
def parse_results(res):
    for result in res:
        if ('business_status' not in result or result['business_status'] != 'CLOSED_PERMANENTLY'): 
            if not result['place_id'] in places:
                places[result['place_id']] = result

# %%
for text in neighbourhoods:
    data = query(text)
    while data is not None:
        time.sleep(2000 * 0.001)
        parse_results(data['results'])
        if 'next_page_token' in data:
    #         print(data['next_page_token'])
            data = query(text, data['next_page_token'])
        else:
            data = None
        print(f'{len(places.keys())} places parsed')
# Out:
# 0 places parsed
# 20 places parsed
# 40 places parsed
# 60 places parsed
# 80 places parsed
# 99 places parsed
# 118 places parsed
# 132 places parsed
# 148 places parsed
# 167 places parsed
# 179 places parsed
# 194 places parsed
# 209 places parsed
# 224 places parsed
# 230 places parsed
# 236 places parsed
# 242 places parsed
# 248 places parsed
# 253 places parsed
# 271 places parsed
# 289 places parsed
# 290 places parsed
# 310 places parsed
# 313 places parsed
# 326 places parsed
# 332 places parsed
# 343 places parsed
# 355 places parsed
# 361 places parsed
# 381 places parsed
# 398 places parsed
# 403 places parsed
# 416 places parsed
# 428 places parsed
# 446 places parsed
# 462 places parsed
# 471 places parsed
# 475 places parsed
# 483 places parsed
# 483 places parsed
# 486 places parsed
# 492 places parsed
# 501 places parsed
# 506 places parsed
# 509 places parsed
# 518 places parsed
# 530 places parsed
# 539 places parsed
# 544 places parsed
# 554 places parsed
# ...

# %%
places
# Out:
# {'ChIJwWzLpZUJxkcRb0NEPd-UYn4': {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Utrechtsestraat 20, 1017 VH Amsterdam',
#   'geometry': {'location': {'lat': 52.3647802, 'lng': 4.8977936},
#    'viewport': {'northeast': {'lat': 52.36605832989272,
#      'lng': 4.899277279892722},
#     'southwest': {'lat': 52.36335867010727, 'lng': 4.896577620107278}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'name': 'Naturel Clothing Store',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJwWzLpZUJxkcRb0NEPd-UYn4',
#   'plus_code': {'compound_code': '9V7X+W4 Amsterdam',
#    'global_code': '9F469V7X+W4'},
#   'rating': 4.5,
#   'reference': 'ChIJwWzLpZUJxkcRb0NEPd-UYn4',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 2},
#  'ChIJRd6_UsAJxkcR2Hn9WnR_rr0': {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Rokin 112, 1012 LB Amsterdam',
# ...

# %%
for place_id, place in tqdm(places.items()):
    if not 'detailed_info_retrieved' in place:
        res = gmaps.place(place_id)
        if 'result' in res:
            places[place_id] = { 'detailed_info_retrieved': True, **place, **res['result'] }
# Out:
# 100%|██████████| 1395/1395 [00:00<00:00, 1044831.09it/s]

# %%
for place in places.values():
    print(place['name'])
#     print(place['name'], place.get('website', ''))
# Out:
# Garment p/re-loved clothing + good items
# FOUR Amsterdam
# Div. Amsterdam
# Lemonade kids fashion
# Salvation Army 50 | 50 Discount Store
# Geitenwollenwinkel
# The Stud Store
# Thrift Shop Amsterdam
# Concrete Matter
# Verse
# Div. Damesboudoir
# Zipper
# FAC Shop
# BIGGLES
# Doordeweeks
# Scotch & Soda
# MOISE
# Universe on a T-shirt :: MINI FACTORY
# LENA the fashion library
# Kiloshop Waterlooplein
# Blue Store - WE Fashion
# The Shirt Shop
# Primark
# We Are Labels
# Scotch & Soda
# Scotch & Soda
# Gray Label
# Kiloshop de Pijp
# Eternity Fashion
# Rauw Store
# Moondrop
# Noumenon - vegan fashion brand
# WE Fashion Store
# Dany's Store
# Best T-shirts in Town Nili's
# Naturel Clothing Store
# Baskèts Stores Office
# Loods Kids store Amsterdam
# Scotch & Soda
# Tenue de Nîmes
# Almost Summer store (by Universe on a t-shirt)
# UvA Merchandise Store
# 1 Amsterdam
# The Darling
# KLABU Amsterdam Store
# Episode
# COTTONCAKE
# VLVT Amsterdam
# We Are Vintage
# Denham Flagship Store
# ...

# %%
blacklist = [
    'Scotch & Soda', 'H&M', 'Levi\'s', 'G-Star', 'Primark', 'Zeeman', 'Kiloshop', 'Episode',
    'GANT', 'Daily Paper', 'Noppies', 'America Today', 'WE Fashion', 'Suitsupply',
    'Pauw', 'Superdry', 'Carhartt', 'Uniqlo', 'Dsquared2', 'Claudia Sträter', 'I Do I Do',
    'ICI PARIS', 'Sissy-Boy', 'SUMIBU', 'C&A', 'JD Sports', 'NEW YORKER', 'Hunkemöller',
    'Aktiesport', 'Esprit', 'Kik Textiel', 'Foot Locker', 'Bedrijfskleding', 'Sintpak',
    'MANGO', 'Levis', 'Hollister', 'Intimissimi', 'Abercrombie', 'Stradivarus', 'NEW YORKER',
    'Berschka', 'Drake\'s Luxury Boutique', 'Moda Paris', 'Stüssy', 'JACK & JONES', 'Nike Factory', 
    'HUGO BOSS', 'BOSS Shop', 'kinderkleding', 'Patta', 'VANS Store', 'Bijenkorf', 'C & A',
    'TIMBERLAND', 'eyewear', 'Replay Jeans', 'Das Werk', 'Teuntje', 'Kilosale', 'Children\'s clothing',
    'Yogashop', 'Kenzo', 'Sample Sale', 'HAAS', 'D&G', 'maternity', 'Massimo Dutti', 'Ralph Lauren',
    'Burberry', 'CHANEL', 'DIOR', 'Lacoste', 'Tommy Hilfiger', 'Hackett London', 'North Face', 'The North Face',
    'SocksWeLove', 'Nike Store', 'Hema', 'Tabaksspeciaalzaak', 'Thrift Store', 'ONLY', 'Parfum', 'Bridal',
    'ZARA', 'COC', 'GUESS', 'Wholesale', 'Fjällräven', 'Geboortekaartjes'
]

parse_blackword = lambda w: w if w == w.upper() else w.lower()
blacklist_parsed = [parse_blackword(w) for w in blacklist]

def is_in_blacklist(place, blacklist):
    for item in blacklist:
        if not item.upper() == item:
            name = place['name'].lower()
        else:
            name = place['name']
        if item in name:
            return True
    return False

# %%
places_filtered = {}
for pid, place in places.items():
    if not is_in_blacklist(place, blacklist_parsed):
        places_filtered[pid] = place

# %%
print(list(places_filtered.values())[0].keys())
# Out:
# dict_keys(['detailed_info_retrieved', 'business_status', 'formatted_address', 'geometry', 'icon', 'name', 'opening_hours', 'photos', 'place_id', 'plus_code', 'rating', 'reference', 'types', 'user_ratings_total', 'address_components', 'adr_address', 'formatted_phone_number', 'international_phone_number', 'reviews', 'url', 'utc_offset', 'vicinity', 'website'])

# %%
print('filtered places:', len(places_filtered))
for pid, place in places_filtered.items():
    print(place['name'], place.get('website', ''))
# Out:
# filtered places: 1144
# Garment p/re-loved clothing + good items http://www.garment.nl/
# FOUR Amsterdam http://www.fouramsterdam.com/
# Div. Amsterdam http://www.divamsterdam.com/
# Lemonade kids fashion http://www.mylemonade.nl/
# Salvation Army 50 | 50 Discount Store http://www.5050-workcenter.nl/labels/budgetstore
# Geitenwollenwinkel http://geitenwollenwinkel.nl/
# The Stud Store http://www.thestud.nl/
# Thrift Shop Amsterdam http://www.thriftshop.amsterdam/
# Concrete Matter https://concrete-matter.com/
# Verse http://www.versegoodstore.com/
# Div. Damesboudoir http://www.divamsterdam.com/
# Zipper http://www.zippervintageclothing.com/
# FAC Shop http://facshop.nl/
# BIGGLES http://www.bigglesamsterdam.nl/
# Doordeweeks http://www.doordeweeks.com/
# MOISE http://www.moise-store.com/
# Universe on a T-shirt :: MINI FACTORY http://www.universeonatshirt.com/
# LENA the fashion library http://www.lena-library.com/
# The Shirt Shop https://www.shirtshopamsterdam.com/
# ...

# %%
blacklist_fields = [
    'icon', 'detailed_info_retrieved', 'business_status', 'address_components', 'adr_address', 'formatted_phone_number', 'utc_offset'
]
def remove_fields(dic, blacklist):
    return { k: v for k, v in dic.items() if not k in blacklist }

# %%
places_filtered = {
    pid: remove_fields(val, blacklist_fields) for pid, val in places_filtered.items()
}

# %%
import json

# %%
with open('/Users/jeroen/code/JeroenPJ/wavedash/shops.json', 'w') as json_file:
    json.dump(places_filtered, json_file)
